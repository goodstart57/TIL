# %% [markdown]
# <h1 style="text-align: center">파이썬으로 구글 스프레드시트 읽는법<br>(How to Read Google SpreadSheet in Python)</h1>
#
#
#
# ## 0. Setting
#
# ### Google SpreadSheet API 사용 권한 얻기
#
# 아래 원본 링크에서 `ENABLE THE GOOGLE SHEETS API`에 들어가서
#
# [원본 링크](https://developers.google.com/sheets/api/quickstart/python?refresh=1)
#
# 1. 새 프로젝트 생성
#
# 2. `credentials.json`이라는 이름의 Configuration File 다운로드 받고 작업 경로에 이동
#
#
# ### Download Module
#
# `google-api-python-client`
#
# `oauth2client`
#
# ```cmd
# pip install --upgrade google-api-python-client oauth2client
# ```
#
# ## 1. Sample Code

# %%
from __future__ import print_function
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools

# If modifying these scopes, delete the file token.json.
SCOPES = 'https://www.googleapis.com/auth/spreadsheets.readonly'

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '18xHkuSevzX9NmkDQT5iaPXUFgxeh3R9MazgS3r9gH-g'
SAMPLE_RANGE_NAME = 'Class Data!A2:E'

"""Shows basic usage of the Sheets API.
Prints values from a sample spreadsheet.
"""
store = file.Storage('token.json')

# %%
creds = store.get()
# Out:
# C:\0Python\Anaconda3-5.2.0x86\lib\site-packages\oauth2client\_helpers.py:255: UserWarning: Cannot access token.json: No such file or directory
#   warnings.warn(_MISSING_FILE_MESSAGE.format(filename))

# %%
if not creds or creds.invalid:
    flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
    creds = tools.run_flow(flow, store)
service = build('sheets', 'v4', http=creds.authorize(Http()))

# Call the Sheets API
SPREADSHEET_ID = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
RANGE_NAME = 'Class Data!A2:E'
result = service.spreadsheets().values().get(spreadsheetId=SPREADSHEET_ID,
                                            range=RANGE_NAME).execute()
values = result.get('values', [])

if not values:
    print('No data found.')
else:
    print('Name, Major:')
    for row in values:
        # Print columns A and E, which correspond to indices 0 and 4.
        print('%s, %s' % (row[0], row[4]))
# Out:
# C:\0Python\Anaconda3-5.2.0x86\lib\site-packages\oauth2client\_helpers.py:255: UserWarning: Cannot access token.json: No such file or directory
#   warnings.warn(_MISSING_FILE_MESSAGE.format(filename))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\0Python\Anaconda3-5.2.0x86\lib\site-packages\oauth2client\clientsecrets.py in _loadfile(filename)
#     120     try:
# --> 121         with open(filename, 'r') as fp:
#     122             obj = json.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'credentials.json'
#
# During handling of the above exception, another exception occurred:
#
# InvalidClientSecretsError                 Traceback (most recent call last)
# <ipython-input-1-c2127cf888ab> in <module>()
#      18 creds = store.get()
#      19 if not creds or creds.invalid:
# ...

# %%
import os
os.chdir("../bigspartner/bigs/KHOpenAPI")

# %%
import gspread

from glob import glob
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

json_file_path = glob("./data/*.json")[0]
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_path, scope)

gc = gspread.authorize(credentials)
gc.login()
wks = gc.open_by_key("18xHkuSevzX9NmkDQT5iaPXUFgxeh3R9MazgS3r9gH-g")
sci = wks.worksheet('Sheet1')

# %%
a = sci.get_all_records()

# %%
import os
os.chdir("../bigspartner/bigs/KHOpenAPI")

# %%
from pykiwoom.kiwoom import *
from pykiwoom.wrapper import *
from pykiwoom.utils.utils import *

import pandas as pd

kiwoom = Kiwoom()
wrapper = KiwoomWrapper(kiwoom)

wrapper.kiwoom.comm_connect()
# Out:
# login successfully
# USER_NAME : 이진수
# 2개의 계좌 중 1번째 계좌 8108691611 선택
# Conditional Search List Load(GetConditionLoad) : Success

# %%
get_near_date_early_time_log_file_path("./log_today_stock/")
# Out:
# 'C:\\0Python\\Workspace-Python\\bigspartner\\bigs\\KHOpenAPI\\log_today_stock\\log_today_stock_20181031_0840.csv'

# %%
ts_update = pd.read_csv(get_near_date_early_time_log_file_path("./log_today_stock/"))
ts_update = ts_update[['순위', '종목코드']]
ts_update_info = wrapper.stock_list_to_info_df(list(ts_update['종목코드'].apply(lambda x: x[1:])))[['종목코드', '종목명', '시가']]
ts_update_info['종목코드'] = ts_update_info['종목코드'].apply(lambda x: 'a'+x)
ts_update_info['시가'] = ts_update_info['시가'].apply(lambda x: int(x))
ts_update = pd.merge(ts_update, ts_update_info, on='종목코드')
ts_update['손절가'] = ts_update.apply(lambda x: "손절가: "+change_scale(x, 0.05)+"원 이탈", axis=1)
ts_update['매수가'] = ts_update.apply(lambda x: "매수구간: "+change_scale(x, 0.02)+"~"+change_scale(x, -0.02)+"원", axis=1)
ts_update.index = range(1, 10)

# if is_post==1:
#     print("오늘의 종목 데이터베이스에 전송 중...")
#     ts_update_json = ts_update.to_json(orient="split")
#     params = {'data_update':ts_update_json}
#     response = requests.post(url=args["url"], data=params)
#     print(response)
#     print("오늘의 종목 데이터베이스에 성공적으로 전송" if response.status_code==200 else "전송 상태 불량")
#     if response.status_code==200:
#         logger.info("[{}] successfully send today stock list to server({})".format(response.status_code, args["url"]))
#     else:
#         logger.error("[{}] failed to send today stock list to server({})".format(response.status_code, args["url"]))
# else:
#     logger.info("test to post...")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:09<00:00,  1.37it/s]

# %%
class ts():
    ts_code = ""
    
ts.ts_code = 'a214330'
ts_update.loc[ts_update['종목코드']==ts.ts_code, '시가'].values[-1]
# Out:
# 0

# %%
# Out:
#    순위     종목코드   종목명_x 시가_x   종목명_y  시가_y     종목명  시가         손절가         매수가
# 1   1  a061970   엘비세미콘    0   엘비세미콘   0.0   엘비세미콘   0  손절가: 0원 이탈  매수구간: 0~0원
# 2   2  a064350    현대로템    0    현대로템   0.0    현대로템   0  손절가: 0원 이탈  매수구간: 0~0원
# 3   3  a044180    KD건설    0    KD건설   0.0    KD건설   0  손절가: 0원 이탈  매수구간: 0~0원
# 4   4  a043100   솔고바이오    0   솔고바이오   0.0   솔고바이오   0  손절가: 0원 이탈  매수구간: 0~0원
# 5   5  a008350   남선알미늄    0   남선알미늄   0.0   남선알미늄   0  손절가: 0원 이탈  매수구간: 0~0원
# 6   6  a045890   DB라이텍    0   DB라이텍   0.0   DB라이텍   0  손절가: 0원 이탈  매수구간: 0~0원
# 7   7  a097520    엠씨넥스    0    엠씨넥스   0.0    엠씨넥스   0  손절가: 0원 이탈  매수구간: 0~0원
# 8   8  a026890     디피씨    0     디피씨   0.0     디피씨   0  손절가: 0원 이탈  매수구간: 0~0원
# 9   9  a214330  금호에이치티    0  금호에이치티   0.0  금호에이치티   0  손절가: 0원 이탈  매수구간: 0~0원

# %%
ts_update
# Out:
#    순위     종목코드
# 0   1  a061970
# 1   2  a064350
# 2   3  a044180
# 3   4  a043100
# 4   5  a008350
# 5   6  a045890
# 6   7  a097520
# 7   8  a026890
# 8   9  a214330

# %%
wrapper.stock_list_to_info_df(list(ts_update['종목코드'].apply(lambda x: x[1:])))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.95it/s]
#                           날짜    종목코드     종목명    현재가 시가 고가 저가 대비기호 전일대비   등락율  \
# 0 2018-11-01 06:20:52.680797  061970   엘비세미콘   3915  0  0  0    3    0  0.00
# 1 2018-11-01 06:20:53.005137  064350    현대로템  21850  0  0  0    3    0  0.00
# 2 2018-11-01 06:20:53.339017  044180    KD건설    107  0  0  0    3    0  0.00
# 3 2018-11-01 06:20:53.674517  043100   솔고바이오    410  0  0  0    3    0  0.00
# 4 2018-11-01 06:20:54.033507  008350   남선알미늄   1380  0  0  0    3    0  0.00
# 5 2018-11-01 06:20:54.342501  045890   DB라이텍   2770  0  0  0    3    0  0.00
# 6 2018-11-01 06:20:54.673309  097520    엠씨넥스  14300  0  0  0    3    0  0.00
# 7 2018-11-01 06:20:55.010254  026890     디피씨   6720  0  0  0    3    0  0.00
# 8 2018-11-01 06:20:55.361186  214330  금호에이치티   8170  0  0  0    3    0  0.00
#
#   거래량  거래대비
# 0   0  0.00
# 1   0  0.00
# 2   0  0.00
# 3   0  0.00
# ...

# %%
kiwoo
# Out:
#    순위     종목코드  종목명   시가
# 0   1  a061970  NaN  NaN
# 1   2  a064350  NaN  NaN
# 2   3  a044180  NaN  NaN
# 3   4  a043100  NaN  NaN
# 4   5  a008350  NaN  NaN
# 5   6  a045890  NaN  NaN
# 6   7  a097520  NaN  NaN
# 7   8  a026890  NaN  NaN
# 8   9  a214330  NaN  NaN

# %%
from pykiwoom.utils.utils import *
from datetime import datetime
from glob import glob

import pandas as pd

# %%
last_stock_file_df['path'].apply(lambda x: x.split("."))
# Out:
# 0     [, /log_today_stock\log_today_stock_20180927_2...
# 1     [, /log_today_stock\log_today_stock_20180928_0...
# 2     [, /log_today_stock\log_today_stock_20181001_0...
# 3     [, /log_today_stock\log_today_stock_20181002_0...
# 4     [, /log_today_stock\log_today_stock_20181004_0...
# 5     [, /log_today_stock\log_today_stock_20181005_0...
# 6     [, /log_today_stock\log_today_stock_20181008_0...
# 7     [, /log_today_stock\log_today_stock_20181008_1...
# 8     [, /log_today_stock\log_today_stock_20181010_0...
# 9     [, /log_today_stock\log_today_stock_20181010_1...
# 10    [, /log_today_stock\log_today_stock_20181010_1...
# 11    [, /log_today_stock\log_today_stock_20181011_1...
# 12    [, /log_today_stock\log_today_stock_20181012_0...
# 13    [, /log_today_stock\log_today_stock_20181015_0...
# 14    [, /log_today_stock\log_today_stock_20181015_1...
# 15    [, /log_today_stock\log_today_stock_20181015_1...
# 16    [, /log_today_stock\log_today_stock_20181015_1...
# ...

# %%
# get_near_date_early_time_log_file_path("./log_today_stock/")
save_path = "./log_today_stock/"
last_stock_file_list = glob(os.path.join(save_path, "*"))
last_stock_file_df = pd.DataFrame({"path": last_stock_file_list})
last_stock_file_df['date'] = last_stock_file_df['path'].apply(lambda x: datetime.strptime(x.split(".")[0][-13:-5], "%Y%m%d"))
last_stock_file_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-3ec1df83158c> in <module>()
#       3 last_stock_file_list = glob(os.path.join(save_path, "*"))
#       4 last_stock_file_df = pd.DataFrame({"path": last_stock_file_list})
# ----> 5 last_stock_file_df['date'] = last_stock_file_df['path'].apply(lambda x: datetime.strptime(x.split(".")[0][-13:-5], "%Y%m%d"))
#       6 last_stock_file_df
#
# C:\0Python\Anaconda3-5.2.0x86\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
# get_near_date_early_time_log_file_path("./log_today_stock/")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-c733d227bc4c> in <module>()
# ----> 1 get_near_date_early_time_log_file_path("./log_today_stock/")
#       2 last_stock_file_df = pd.DataFrame({"path": last_stock_file_list})
#       3 last_stock_file_df['date'] = last_stock_file_df['path'].apply(lambda x: datetime.strptime(x.split(".")[0][-13:-5], "%Y%m%d"))
#       4 last_stock_file_df
#
# C:\0Python\Workspace-Python\bigspartner\bigs\KHOpenAPI\pykiwoom\utils\utils.py in get_near_date_early_time_log_file_path(save_path)
#      99     last_stock_file_list = glob(os.path.join(save_path, "*"))
#     100     last_stock_file_df = pd.DataFrame({"path": last_stock_file_list})
# --> 101     last_stock_file_df['date'] = last_stock_file_df['path'].apply(lambda x: datetime.strptime(x.split(".")[0][-13:-5], "%Y%m%d"))
# ...

# %%
for row in a:
    if 'a214330'==row['stock_id']:
        print(row)
# Out:
# {'stock_id': 'a214330', 'stock_name': '금호에이치티', 'category': 'LED', '섹터기업요약': '\xa0금호전기 계열의 자동차용 조명 전문 제조 업체. 조명의 광원에 따라 LED모듈 사업부 및 백열전구(BULB) 사업부로 구분지어 사업을 영위중이며, 차량 전면/후면 조명장치, 계기판, 실내등 등 자동차에 사용되는 전 부문의 조명을 생산중.'}
# {'stock_id': 'a214330', 'stock_name': '금호에이치티', 'category': '자동차부품', '섹터기업요약': '\xa0금호전기 계열의 자동차용 조명 전문 제조 업체. 조명의 광원에 따라 LED모듈 사업부 및 백열전구(BULB) 사업부로 구분지어 사업을 영위중이며, 차량 전면/후면 조명장치, 계기판, 실내등 등 자동차에 사용되는 전 부문의 조명을 생산중.'}
